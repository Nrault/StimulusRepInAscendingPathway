# %%
plot(L4I_activity.t/ms, L4I_activity.Inoise[1]/mV)
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Tansu Celikel\.vscode\extensions\ms-python.python-2024.22.1-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# NameError: name 'plot' is not defined

# %%
plt.plot(L4I_activity.t/ms, L4I_activity.Inoise[1]/mV)
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Tansu Celikel\.vscode\extensions\ms-python.python-2024.22.1-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# NameError: name 'plt' is not defined
