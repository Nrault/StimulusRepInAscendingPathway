# %%
from sklearn.metrics import mutual_info_score
from os import listdir
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import entropy, pearsonr
#from dit import Distribution
#from dit.multivariate import coinformation
import seaborn as sns
from collections import Counter

new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
plt.rcParams.update(new_rc_params)

# %%
def load_data(population, var_of_interest):
    neural_act = []
    stim_id = []
    lst = listdir('./neural_activity/' + population + var_of_interest)
    sorted_files = sorted(lst, key=lambda x: int(x.split('.')[0]))
    for f in sorted_files:
        neural_act.append(np.genfromtxt('./neural_activity/' + population + var_of_interest + '/' + f, delimiter=','))
        stim_id.append(Path(f).stem)
    neural_act = np.asarray(neural_act, dtype="object")
    stim_id = np.asarray(stim_id, dtype=float)
    return neural_act, stim_id

# %%
def load_spiketimes(directory, population, rank):
    neural_act = []
    stim_id = []
    for f in listdir('./neural_activity/' + directory + population + '/spike_time'):
        sp_time = np.genfromtxt('./neural_activity/' + directory + population + '/spike_time' + '/' + f, delimiter=',')
        sp_time = np.unique(sp_time)[rank]
        neural_act.append(sp_time)
        stim_id.append(Path(f).stem)
    neural_act = np.asarray(neural_act)
    return neural_act, np.asarray(stim_id, dtype=int)

# %%
def load_spiketime_per_neuron(directory, population, populationsize, rank):
    neuron_ids, stim_id = load_data(directory, population, '/spike_id')
    neuron_sptime, _ = load_data(directory, population, '/spike_time')
    sp_time_per_neuron = np.zeros((len(stim_id), populationsize))
    for j in range(len(stim_id)):
        #sp_time_per_neuron_per_stim = []
        for i in range(populationsize):
            #sp_time_per_neuron_per_stim.append(neuron_sptime[j][np.where(neuron_ids[j] == i)])
            try:
                sp_time_per_neuron[j, i] = neuron_sptime[j][np.where(neuron_ids[j] == i)][rank]
            except:
                pass
        #sp_time_per_neuron.append(sp_time_per_neuron_per_stim)
    return sp_time_per_neuron, stim_id

# %%
def compute_nb_spike_per_neuron(data, popsize):
    data = np.asarray(data, dtype=int)
    spike_per_neuron = np.zeros(popsize)
    for i in np.unique(data):
        spike_per_neuron[i] = np.sum(np.where(data == i, 1, 0))

    return spike_per_neuron

# %%
Parameters = ['0_amplitude']#, '0_direction', '0_distance_to_basis', '0_frequency', '0_slope_speed']
Populations = ['SA1', 'SA2', 'RA', 'TG', 'BS', 'TC', 'L4E', 'L4I', 'L3E', 'L3I', 'L2E', 'L2I']
Populations_sizes = [24, 10, 36, 70, 70, 70, 188, 33, 158, 28, 86, 15]
for param in Parameters:
    correlation_per_neuron_per_pop_mean = []
    correlation_per_neuron_per_pop_std = []
    for j in range(len(Populations)):
        correlation_per_neuron = []
        popsize = Populations_sizes[j]
        neural_act, stim_id = load_data(Populations[j], '/spike_id')
        spike_per_neuron_per_stimulus = np.zeros((len(neural_act), popsize))
        for i in range(len(spike_per_neuron_per_stimulus)):
            spike_per_neuron_per_stimulus[i] = compute_nb_spike_per_neuron(neural_act[i], popsize)
        co_inf = np.zeros((popsize, popsize))
        for i in range(popsize):
            for y in range(popsize):
                #if np.unique(spike_per_neuron_per_stimulus[:, i]) != 0 and np.unique(spike_per_neuron_per_stimulus[:, y]) != 0:
                pearson = pearsonr(spike_per_neuron_per_stimulus[:, i], spike_per_neuron_per_stimulus[:, y])[0]#mutual_info_score(spike_per_neuron_per_stimulus[:, i], spike_per_neuron_per_stimulus[:, y])/np.log(2)
                #print(spike_per_neuron_per_stimulus[:, j])
                #if (not np.isnan(pearson)) and (pearson != 0) and not(np.isclose(pearson, 0, atol=1e-10)):
                if np.isnan(pearson):
                    pearson=0
                correlation_per_neuron.append(pearson)
        #    for k in range(popsize):
        #        co_inf[i, k] = co_information(spike_per_neuron_per_stimulus[:, i], spike_per_neuron_per_stimulus[:, k], stim_id)
        #sns.heatmap(co_inf)
        #plt.show()
        correlation_per_neuron = np.asarray(correlation_per_neuron)
        correlation_per_neuron = correlation_per_neuron[correlation_per_neuron > 0]
        if np.isnan(correlation_per_neuron.mean()):
            mean = 0
            std = 0
        else:
            mean = correlation_per_neuron.mean()
            std = correlation_per_neuron.std()
        correlation_per_neuron_per_pop_mean.append(mean)
        correlation_per_neuron_per_pop_std.append(std)
        #plt.scatter(j, mutual_info_score(spike_per_neuron_per_stimulus.sum(axis=1), stim_id)/np.log(2))
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
    coord = np.deg2rad(np.linspace(0, 360, num=13, dtype=int))
    correlation_per_neuron_per_pop_mean.append(correlation_per_neuron_per_pop_mean[0])
    ax.plot(coord, np.asarray(correlation_per_neuron_per_pop_mean))
    ax.set_xticks(coord[:-1])
    ax.set_xticklabels(['SA1', 'SA2', 'RA', 'TG', 'BS', 'TC', 'L4E', 'L4I', 'L3E', 'L3I', 'L2E', 'L2I'])
    correlation_per_neuron_per_pop_std.append(correlation_per_neuron_per_pop_std[0])
    std_plus = np.asarray(correlation_per_neuron_per_pop_mean) + np.asarray(correlation_per_neuron_per_pop_std)
    std_minus = np.asarray(correlation_per_neuron_per_pop_mean) - np.asarray(correlation_per_neuron_per_pop_std)
    ax.fill_between(coord, std_plus, std_minus, alpha=0.2)
    ax.set_title(param)
    ax.set_ylim(0, 1)
    #ax.plot(coord, , linestyle='dashed')
    #ax.plot(coord, , linestyle='dashed')
    #plt.violinplot(correlation_per_neuron_per_pop)    
    #plt.xticks(np.arange(1,6), Populations)
    plt.savefig('./Figures/Correlation/Pearson_bis' + param + '.svg')
    plt.show()
# Out:
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\2097466828.py:18: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pearson = pearsonr(spike_per_neuron_per_stimulus[:, i], spike_per_neuron_per_stimulus[:, y])[0]#mutual_info_score(spike_per_neuron_per_stimulus[:, i], spike_per_neuron_per_stimulus[:, y])/np.log(2)
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/3.8800673096963036.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/4.092282469836162.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/4.63969768863419.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/4.651936378474336.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/5.498343136656712.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/5.689475403888284.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/7.852482423296125.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/8.53950421443118.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/9.449966195984624.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/10.294823130976344.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/11.231072984541685.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/11.621697467202347.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/12.536086439851276.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/12.540131143538947.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/13.629265712602997.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/13.737617278181219.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/13.931187466655278.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/14.886901894535049.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/15.082062500591126.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/16.21041489622112.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/16.458784827829447.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/16.727851465206932.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/16.811894518794137.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/18.396912649053824.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/19.08630500464488.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/19.65802605069553.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/19.863884373156104.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/19.91986227559658.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/20.14826109747925.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/20.695481179070235.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/20.797592987199252.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/22.26945747984965.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/22.991380009437815.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/23.10450269788808.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/23.54403469522709.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/24.214858435977135.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/24.3721072365258.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/25.41226668745.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/26.280374792284203.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/26.716507164226446.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/27.89013484151992.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/28.129923434776476.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/28.375624379056685.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/28.474996690675614.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/28.67422161920789.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/28.950481124579685.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/29.013497273104715.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/29.306024880945202.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/29.429625713839965.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/29.570325201874013.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/30.99352853470982.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/31.36305157016018.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/32.50818469525829.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/32.580675802960876.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/32.68265100117967.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/33.45346933552055.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/35.6662726931868.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/35.88047367922676.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/SA2/spike_id/35.90175000650379.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/RA/spike_id/4.092282469836162.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
# C:\Users\Tansu Celikel\AppData\Local\Temp\ipykernel_28948\1463204854.py:7: UserWarning: genfromtxt: Empty input file: "./neural_activity_bis/RA/spike_id/4.651936378474336.csv"
#   neural_act.append(np.genfromtxt('./neural_activity_bis/' + population + var_of_interest + '/' + f, delimiter=','))
